# %%
import pandas as pd
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install scipy

# %%
data = pd.read_csv('data/dataset.csv')

# %%
sample = data.sample(33)
sample.head()
# Out:
#              objid          ra        dec         u         g         r  \
# 6416  1.237650e+18   11.368378  14.703752  19.33779  18.32987  17.93420
# 4726  1.237650e+18  131.952629  52.589983  18.54162  17.24359  16.53755
# 5120  1.237650e+18  184.353008  -1.736801  19.43036  18.26814  17.70304
# 4013  1.237650e+18  160.215744   1.096871  19.44259  18.00743  17.25014
# 2279  1.237650e+18  151.332755   0.275259  19.36382  18.08251  17.33688
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 6416  17.82492  17.73175  1035    301       3     39  6.984080e+18    STAR
# 4726  16.16176  15.92815  1345    301       4    168  5.034100e+17  GALAXY
# 5120  17.36375  17.18789  1140    301       5    210  3.750370e+17  GALAXY
# 4013  16.84793  16.59558   756    301       6    296  3.086410e+17  GALAXY
# 2279  16.97474  16.66946   756    301       4    237  3.030020e+17  GALAXY
#
#       redshift  plate    mjd  fiberid
# 6416 -0.000774   6203  56266      454
# ...

# %%
sect1 = pd.DataFrame({
	x: sample[x] for x in ['ra', 'dec', 'class']
})
sect1.head()
# Out:
#               ra        dec   class
# 6416   11.368378  14.703752    STAR
# 4726  131.952629  52.589983  GALAXY
# 5120  184.353008  -1.736801  GALAXY
# 4013  160.215744   1.096871  GALAXY
# 2279  151.332755   0.275259  GALAXY

# %%
sect2 = pd.DataFrame({
	x: sample[x] for x in ['u', 'g', 'r', 'i', 'z', 'class']
})
sect2.head()
# Out:
#              u         g         r         i         z   class
# 6416  19.33779  18.32987  17.93420  17.82492  17.73175    STAR
# 4726  18.54162  17.24359  16.53755  16.16176  15.92815  GALAXY
# 5120  19.43036  18.26814  17.70304  17.36375  17.18789  GALAXY
# 4013  19.44259  18.00743  17.25014  16.84793  16.59558  GALAXY
# 2279  19.36382  18.08251  17.33688  16.97474  16.66946  GALAXY

# %%
sect3 = pd.DataFrame({
	x: sample[x] for x in ['run', 'rerun', 'camcol', 'field', 'specobjid', 'class']
})
sect3.head()
# Out:
#        run  rerun  camcol  field     specobjid   class
# 6416  1035    301       3     39  6.984080e+18    STAR
# 4726  1345    301       4    168  5.034100e+17  GALAXY
# 5120  1140    301       5    210  3.750370e+17  GALAXY
# 4013   756    301       6    296  3.086410e+17  GALAXY
# 2279   756    301       4    237  3.030020e+17  GALAXY

# %%
sect4 = pd.DataFrame({
	x: sample[x] for x in ['redshift', 'plate', 'mjd', 'fiberid', 'class']
})
sect4.head()
# Out:
#       redshift  plate    mjd  fiberid   class
# 6416 -0.000774   6203  56266      454    STAR
# 4726  0.086951    447  51877      482  GALAXY
# 5120  0.088079    333  52313      410  GALAXY
# 4013  0.106391    274  51913      527  GALAXY
# 2279  0.125232    269  51910      492  GALAXY
